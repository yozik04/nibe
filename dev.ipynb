# %%
import json
import re
import pandas as pandas
from slugify.slugify import slugify

from nibe_modbus.heatpump import Model

model = Model.F1255

file = model.get_data_file(extension='csv')

# %%
data = pandas.read_csv(file, sep=";", skiprows=4, encoding='latin1', index_col=False, skipinitialspace=True)

# lowercase column names
data.columns = map(str.lower, data.columns)
data.set_index('id', inplace=True)
data
# Out:
#                                            title  \
# id
# 32260                    NIBE Inverter 216-state
# 40004                    BT1 Outdoor Temperature
# 40005                    EP23-BT2 Supply temp S4
# 40006                    EP22-BT2 Supply temp S3
# 40007                    EP21-BT2 Supply temp S2
# ...                                          ...
# 49378  External ERS 2 accessory bypass set temp.
# 49379    External ERS 4 accessory bypass at heat
# 49380    External ERS 3 accessory bypass at heat
# 49381    External ERS 2 accessory bypass at heat
# 49430                   AUX ERS Fire Place Guard
#
#                                   info unit size  factor  min  max  default  \
# id
# 32260                              NaN  NaN   u8       1    0    0        0
# 40004      Current outdoor temperature   °C  s16      10    0    0        0
# 40005  Supply temperature for system 4   °C  s16      10    0    0        0
# 40006  Supply temperature for system 3   °C  s16      10    0    0        0
# 40007  Supply temperature for system 2   °C  s16      10    0    0        0
# ...                                ...  ...  ...     ...  ...  ...      ...
# 49378                              NaN   °C   u8       1    5   30       25
# 49379                              NaN  NaN   u8       1    0    1        0
# 49380                              NaN  NaN   u8       1    0    1        0
# 49381                              NaN  NaN   u8       1    0    1        0
# 49430   Activates ERS Fire Place Guard  NaN   u8       1    0    0        0
#
#       mode
# id
# 32260    R
# 40004    R
# 40005    R
# 40006    R
# 40007    R
# ...    ...
# 49378  R/W
# 49379  R/W
# 49380  R/W
# 49381  R/W
# 49430  R/W
#
# [976 rows x 9 columns]

# %%
data['unit'] = data['unit'].replace(r'^\s*$', pandas.NA, regex=True)

# Make name
data['name'] = pandas.Series(data.index, index=data.index).combine(data['title'], lambda id_, title: slugify(f"{title}-{id_}")).astype('string')

# Set types
data['title'] = data['title'].astype('string')
data['info'] = data['info'].astype('string')
data['unit'] = data['unit'].str.strip().astype('string')
data['mode'] = data['mode'].str.strip().astype('string')
data['size'] = data['size'].astype('string')

data['write'] = data['mode'].map(lambda x: x == 'R/W')
valid_min_max = data['min'] != data['max']

data['min'] = data['min'].where(valid_min_max)
data['max'] = data['max'].where(valid_min_max)
data['default'] = data['default'].where(valid_min_max)
data
# Out:
#                                            title  \
# id
# 32260                    NIBE Inverter 216-state
# 40004                    BT1 Outdoor Temperature
# 40005                    EP23-BT2 Supply temp S4
# 40006                    EP22-BT2 Supply temp S3
# 40007                    EP21-BT2 Supply temp S2
# ...                                          ...
# 49378  External ERS 2 accessory bypass set temp.
# 49379    External ERS 4 accessory bypass at heat
# 49380    External ERS 3 accessory bypass at heat
# 49381    External ERS 2 accessory bypass at heat
# 49430                   AUX ERS Fire Place Guard
#
#                                   info  unit size  factor  min   max  default  \
# id
# 32260                             <NA>  <NA>   u8       1  NaN   NaN      NaN
# 40004      Current outdoor temperature    °C  s16      10  NaN   NaN      NaN
# 40005  Supply temperature for system 4    °C  s16      10  NaN   NaN      NaN
# 40006  Supply temperature for system 3    °C  s16      10  NaN   NaN      NaN
# 40007  Supply temperature for system 2    °C  s16      10  NaN   NaN      NaN
# ...                                ...   ...  ...     ...  ...   ...      ...
# 49378                             <NA>    °C   u8       1  5.0  30.0     25.0
# 49379                             <NA>  <NA>   u8       1  0.0   1.0      0.0
# 49380                             <NA>  <NA>   u8       1  0.0   1.0      0.0
# 49381                             <NA>  <NA>   u8       1  0.0   1.0      0.0
# 49430   Activates ERS Fire Place Guard  <NA>   u8       1  NaN   NaN      NaN
#
#       mode                                            name  write
# id
# 32260    R                   nibe-inverter-216-state-32260  False
# 40004    R                   bt1-outdoor-temperature-40004  False
# 40005    R                   ep23-bt2-supply-temp-s4-40005  False
# 40006    R                   ep22-bt2-supply-temp-s3-40006  False
# 40007    R                   ep21-bt2-supply-temp-s2-40007  False
# ...    ...                                             ...    ...
# 49378  R/W  external-ers-2-accessory-bypass-set-temp-49378   True
# 49379  R/W   external-ers-4-accessory-bypass-at-heat-49379   True
# 49380  R/W   external-ers-3-accessory-bypass-at-heat-49380   True
# 49381  R/W   external-ers-2-accessory-bypass-at-heat-49381   True
# 49430  R/W                  aux-ers-fire-place-guard-49430   True
#
# [976 rows x 11 columns]

# %%
with_equal = data['info'].where(data['info'].str.contains('=')).dropna()

# %%
# Mappings
re_mapping = re.compile(r'(?P<value>\d+|I)\s*=\s*(?P<key>(?:[\w +.-]+[\w]\b[+]?(?! *=)))', re.IGNORECASE)
mappings = data['info'].where(~data['info'].str.contains("encoded")).str.extractall(re_mapping)
mappings['value'] = mappings['value'].str.replace('I', '1').astype('int')
mappings = mappings.reset_index("match", drop=True)
# mappings['id'] = mappings.index
mappings = mappings.drop_duplicates()
# del mappings['id']
mappings
# Out:
#        value                     key
# id
# 40912     10                     off
# 40912     40             active wait
# 40912     50                  active
# 40913     10               shunt off
# 40913     20              shunt open
# ...      ...                     ...
# 49193      0                  manual
# 49193      1         auto controlled
# 49193      2  fixed delta controlled
# 49292      0                  0V-10V
# 49292      1                  10V-0V
#
# [103 rows x 2 columns]

# %%
mappings
# Out:
#        value                     key
# id
# 40912     10                     off
# 40912     40             active wait
# 40912     50                  active
# 40913     10               shunt off
# 40913     20              shunt open
# ...      ...                     ...
# 49193      0                  manual
# 49193      1         auto controlled
# 49193      2  fixed delta controlled
# 49292      0                  0V-10V
# 49292      1                  10V-0V
#
# [103 rows x 2 columns]

# %%
data['mappings'] = pandas.Series({k: dict(g.values) for k,g in mappings.groupby('value', level=0)})

# %%
data
# Out:
#                                            title  \
# id
# 32260                    NIBE Inverter 216-state
# 40004                    BT1 Outdoor Temperature
# 40005                    EP23-BT2 Supply temp S4
# 40006                    EP22-BT2 Supply temp S3
# 40007                    EP21-BT2 Supply temp S2
# ...                                          ...
# 49378  External ERS 2 accessory bypass set temp.
# 49379    External ERS 4 accessory bypass at heat
# 49380    External ERS 3 accessory bypass at heat
# 49381    External ERS 2 accessory bypass at heat
# 49430                   AUX ERS Fire Place Guard
#
#                                   info  unit size  factor  min   max  default  \
# id
# 32260                             <NA>  <NA>   u8       1  NaN   NaN      NaN
# 40004      Current outdoor temperature    °C  s16      10  NaN   NaN      NaN
# 40005  Supply temperature for system 4    °C  s16      10  NaN   NaN      NaN
# 40006  Supply temperature for system 3    °C  s16      10  NaN   NaN      NaN
# 40007  Supply temperature for system 2    °C  s16      10  NaN   NaN      NaN
# ...                                ...   ...  ...     ...  ...   ...      ...
# 49378                             <NA>    °C   u8       1  5.0  30.0     25.0
# 49379                             <NA>  <NA>   u8       1  0.0   1.0      0.0
# 49380                             <NA>  <NA>   u8       1  0.0   1.0      0.0
# 49381                             <NA>  <NA>   u8       1  0.0   1.0      0.0
# 49430   Activates ERS Fire Place Guard  <NA>   u8       1  NaN   NaN      NaN
#
#       mode                                            name  write mappings
# id
# 32260    R                   nibe-inverter-216-state-32260  False      NaN
# 40004    R                   bt1-outdoor-temperature-40004  False      NaN
# 40005    R                   ep23-bt2-supply-temp-s4-40005  False      NaN
# 40006    R                   ep22-bt2-supply-temp-s3-40006  False      NaN
# 40007    R                   ep21-bt2-supply-temp-s2-40007  False      NaN
# ...    ...                                             ...    ...      ...
# 49378  R/W  external-ers-2-accessory-bypass-set-temp-49378   True      NaN
# 49379  R/W   external-ers-4-accessory-bypass-at-heat-49379   True      NaN
# 49380  R/W   external-ers-3-accessory-bypass-at-heat-49380   True      NaN
# 49381  R/W   external-ers-2-accessory-bypass-at-heat-49381   True      NaN
# 49430  R/W                  aux-ers-fire-place-guard-49430   True      NaN
#
# [976 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 976 entries, 32260 to 49430
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     976 non-null    string
#  1   info      641 non-null    string
#  2   unit      524 non-null    string
#  3   size      976 non-null    string
#  4   factor    976 non-null    int64
#  5   min       537 non-null    float64
#  6   max       537 non-null    float64
#  7   default   537 non-null    float64
#  8   mode      976 non-null    string
#  9   name      976 non-null    string
#  10  write     976 non-null    bool
#  11  mappings  35 non-null     object
# dtypes: bool(1), float64(3), int64(1), object(1), string(6)
# memory usage: 132.5+ KB

# %%
data['size'].unique()
# Out:
# <StringArray>
# ['u8', 's16', 'u32', 'u16', 's32', 's8']
# Length: 6, dtype: string

# %%
del(data['mode'])
data['write'] = data['write'].map(lambda x: x or pandas.NA)

# %%
js = json.dumps({index: row.dropna().to_dict() for index,row in data.iterrows()}, indent=2)

print(js)
# Out:
# {
#   "32260": {
#     "title": "NIBE Inverter 216-state",
#     "size": "u8",
#     "factor": 1,
#     "name": "nibe-inverter-216-state-32260"
#   },
#   "40004": {
#     "title": "BT1 Outdoor Temperature",
#     "info": "Current outdoor temperature",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt1-outdoor-temperature-40004"
#   },
#   "40005": {
#     "title": "EP23-BT2 Supply temp S4",
#     "info": "Supply temperature for system 4",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep23-bt2-supply-temp-s4-40005"
#   },
#   "40006": {
#     "title": "EP22-BT2 Supply temp S3",
#     "info": "Supply temperature for system 3",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep22-bt2-supply-temp-s3-40006"
#   },
#   "40007": {
#     "title": "EP21-BT2 Supply temp S2",
#     "info": "Supply temperature for system 2",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep21-bt2-supply-temp-s2-40007"
#   },
#   "40008": {
#     "title": "BT2 Supply temp S1",
#     "info": "Supply temperature for system 1",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt2-supply-temp-s1-40008"
#   },
#   "40012": {
#     "title": "EB100-EP14-BT3 Return temp",
#     "info": "Return temperature",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eb100-ep14-bt3-return-temp-40012"
#   },
#   "40013": {
#     "title": "BT7 HW Top",
#     "info": "Hot water top temperature, BT7",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt7-hw-top-40013"
#   },
#   "40014": {
#     "title": "BT6 HW Load",
#     "info": "Hot water load temperature, BT6",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt6-hw-load-40014"
#   },
#   "40015": {
#     "title": "EB100-EP14-BT10 Brine In Temp",
#     "info": "Brine in temperature, BT10",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eb100-ep14-bt10-brine-in-temp-40015"
#   },
#   "40016": {
#     "title": "EB100-EP14-BT11 Brine Out Temp",
#     "info": "Brine out temperature, BT11",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eb100-ep14-bt11-brine-out-temp-40016"
#   },
#   "40017": {
#     "title": "EB100-EP14-BT12 Condensor Out",
#     "info": "Condensor out temperature, BT12",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eb100-ep14-bt12-condensor-out-40017"
#   },
#   "40018": {
#     "title": "EB100-EP14-BT14 Hot Gas Temp",
#     "info": "Hot gas temperature, BT14",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eb100-ep14-bt14-hot-gas-temp-40018"
#   },
#   "40019": {
#     "title": "EB100-EP14-BT15 Liquid Line",
#     "info": "Liquid line temperature, BT15",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eb100-ep14-bt15-liquid-line-40019"
#   },
#   "40022": {
#     "title": "EB100-EP14-BT17 Suction",
#     "info": "Suction temperature, BT17",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eb100-ep14-bt17-suction-40022"
#   },
#   "40025": {
#     "title": "BT20 Exhaust air temp. 1",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt20-exhaust-air-temp-1-40025"
#   },
#   "40026": {
#     "title": "BT21 Vented air temp. 1",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt21-vented-air-temp-1-40026"
#   },
#   "40028": {
#     "title": "AZ1-BT26 Temp Collector in FLM 1",
#     "info": "Connected to the FLM module",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az1-bt26-temp-collector-in-flm-1-40028"
#   },
#   "40029": {
#     "title": "AZ1-BT27 Temp Collector out FLM 1",
#     "info": "Connected to the FLM module",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az1-bt27-temp-collector-out-flm-1-40029"
#   },
#   "40030": {
#     "title": "EP23-BT50 Room Temp S4",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep23-bt50-room-temp-s4-40030"
#   },
#   "40031": {
#     "title": "EP22-BT50 Room Temp S3",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep22-bt50-room-temp-s3-40031"
#   },
#   "40032": {
#     "title": "EP21-BT50 Room Temp S2",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep21-bt50-room-temp-s2-40032"
#   },
#   "40033": {
#     "title": "BT50 Room Temp S1",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt50-room-temp-s1-40033"
#   },
#   "40042": {
#     "title": "CL11-BT51 Pool 1 Temp",
#     "info": "Pool temperature for Pool 1, BT51",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "cl11-bt51-pool-1-temp-40042"
#   },
#   "40043": {
#     "title": "BT53 Solar Panel Temp",
#     "info": "Used in Solar and AHPS Docking accessories",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt53-solar-panel-temp-40043"
#   },
#   "40044": {
#     "title": "BT54 Solar Load Temp",
#     "info": "Used in Solar and AHPS Docking accessories",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt54-solar-load-temp-40044"
#   },
#   "40045": {
#     "title": "EQ1-BT64 Cool Supply Temp",
#     "info": "Cool supply temperature, BT64",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eq1-bt64-cool-supply-temp-40045"
#   },
#   "40046": {
#     "title": "EQ1-BT65 Cool Return Temp",
#     "info": "Cool return temperature, BT65",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eq1-bt65-cool-return-temp-40046"
#   },
#   "40054": {
#     "title": "EB100-FD1 Temperature limiter",
#     "size": "s16",
#     "factor": 1,
#     "name": "eb100-fd1-temperature-limiter-40054"
#   },
#   "40067": {
#     "title": "BT1 Average",
#     "info": "EB100-BT1 Outdoor temperature average",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt1-average-40067"
#   },
#   "40070": {
#     "title": "EM1-BT52 Boiler Temperature",
#     "info": "Boiler temperature, BT52",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "em1-bt52-boiler-temperature-40070"
#   },
#   "40071": {
#     "title": "BT25 Ext. Supply",
#     "info": "External supply temperature, BT25",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt25-ext-supply-40071"
#   },
#   "40072": {
#     "title": "BF1 EP14 Flow",
#     "info": "Current flow EP14|Current flow EP15",
#     "unit": "l/m",
#     "size": "s16",
#     "factor": 10,
#     "name": "bf1-ep14-flow-40072"
#   },
#   "40074": {
#     "title": "EB100-FR1 Anode Status",
#     "size": "s16",
#     "factor": 1,
#     "name": "eb100-fr1-anode-status-40074"
#   },
#   "40075": {
#     "title": "BT22 Supply air temp.",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt22-supply-air-temp-40075"
#   },
#   "40079": {
#     "title": "EB100-BE3 Current",
#     "unit": "A",
#     "size": "u32",
#     "factor": 10,
#     "name": "eb100-be3-current-40079"
#   },
#   "40081": {
#     "title": "EB100-BE2 Current",
#     "unit": "A",
#     "size": "u32",
#     "factor": 10,
#     "name": "eb100-be2-current-40081"
#   },
#   "40083": {
#     "title": "EB100-BE1 Current",
#     "unit": "A",
#     "size": "u32",
#     "factor": 10,
#     "name": "eb100-be1-current-40083"
#   },
#   "40106": {
#     "title": "CL12-BT51 Pool 2 Temp",
#     "info": "Pool temperature for Pool 2, BT51",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "cl12-bt51-pool-2-temp-40106"
#   },
#   "40107": {
#     "title": "BT20 Exhaust air temp. 4",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt20-exhaust-air-temp-4-40107"
#   },
#   "40108": {
#     "title": "BT20 Exhaust air temp. 3",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt20-exhaust-air-temp-3-40108"
#   },
#   "40109": {
#     "title": "BT20 Exhaust air temp. 2",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt20-exhaust-air-temp-2-40109"
#   },
#   "40110": {
#     "title": "BT21 Vented air temp. 4",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt21-vented-air-temp-4-40110"
#   },
#   "40111": {
#     "title": "BT21 Vented air temp. 3",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt21-vented-air-temp-3-40111"
#   },
#   "40112": {
#     "title": "BT21 Vented air temp. 2",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt21-vented-air-temp-2-40112"
#   },
#   "40113": {
#     "title": "AZ4-BT26 Temp Collector in FLM 4",
#     "info": "Connected to the FLM module",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az4-bt26-temp-collector-in-flm-4-40113"
#   },
#   "40114": {
#     "title": "AZ3-BT26 Temp Collector in FLM 3",
#     "info": "Connected to the FLM module",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az3-bt26-temp-collector-in-flm-3-40114"
#   },
#   "40115": {
#     "title": "AZ2-BT26 Temp Collector in FLM 2",
#     "info": "Connected to the FLM module",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az2-bt26-temp-collector-in-flm-2-40115"
#   },
#   "40116": {
#     "title": "AZ4-BT27 Temp Collector out FLM 4",
#     "info": "Connected to the FLM module",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az4-bt27-temp-collector-out-flm-4-40116"
#   },
#   "40117": {
#     "title": "AZ3-BT27 Temp Collector out FLM 3",
#     "info": "Connected to the FLM module",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az3-bt27-temp-collector-out-flm-3-40117"
#   },
#   "40118": {
#     "title": "AZ2-BT27 Temp Collector out FLM 2",
#     "info": "Connected to the FLM module",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az2-bt27-temp-collector-out-flm-2-40118"
#   },
#   "40127": {
#     "title": "EP23-BT3 Return temp S4",
#     "info": "Return temperature for system 4",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep23-bt3-return-temp-s4-40127"
#   },
#   "40128": {
#     "title": "EP22-BT3 Return temp S3",
#     "info": "Return temperature for system 3",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep22-bt3-return-temp-s3-40128"
#   },
#   "40129": {
#     "title": "EP21-BT3 Return temp S2",
#     "info": "Return temperature for system 2",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep21-bt3-return-temp-s2-40129"
#   },
#   "40146": {
#     "title": "EB100-EP14-BT29 Cpr Oil Temp",
#     "info": "Compressor oil temperature, BT29",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eb100-ep14-bt29-cpr-oil-temp-40146"
#   },
#   "40147": {
#     "title": "BT70 HW Comfort Supply Temp.",
#     "info": "Hot water comfort supply temperature, BT70",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt70-hw-comfort-supply-temp-40147"
#   },
#   "40155": {
#     "title": "EQ1-BT57 Collector Temp.",
#     "info": "External collector temperature, BT57, for ACS",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eq1-bt57-collector-temp-40155"
#   },
#   "40156": {
#     "title": "EQ1-BT75 Heatdump Temp.",
#     "info": "Heating medium dump temperature, BT75, for ACS",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "eq1-bt75-heatdump-temp-40156"
#   },
#   "40159": {
#     "title": "EP47-BT2 Supply temp S8",
#     "info": "Supply temperature for system 8",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep47-bt2-supply-temp-s8-40159"
#   },
#   "40160": {
#     "title": "EP46-BT2 Supply temp S7",
#     "info": "Supply temperature for system 7",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep46-bt2-supply-temp-s7-40160"
#   },
#   "40161": {
#     "title": "EP45-BT2 Supply temp S6",
#     "info": "Supply temperature for system 6",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep45-bt2-supply-temp-s6-40161"
#   },
#   "40162": {
#     "title": "EP44-BT2 Supply temp S5",
#     "info": "Supply temperature for system 5",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep44-bt2-supply-temp-s5-40162"
#   },
#   "40163": {
#     "title": "EP47-BT3 Return temp S8",
#     "info": "Return temperature for system 8",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep47-bt3-return-temp-s8-40163"
#   },
#   "40164": {
#     "title": "EP46-BT3 Return temp S7",
#     "info": "Return temperature for system 7",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep46-bt3-return-temp-s7-40164"
#   },
#   "40165": {
#     "title": "EP45-BT3 Return temp S6",
#     "info": "Return temperature for system 6",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep45-bt3-return-temp-s6-40165"
#   },
#   "40166": {
#     "title": "EP44-BT3 Return temp S5",
#     "info": "Return temperature for system 5",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep44-bt3-return-temp-s5-40166"
#   },
#   "40167": {
#     "title": "EP47-BT50 Room Temp S8",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep47-bt50-room-temp-s8-40167"
#   },
#   "40168": {
#     "title": "EP46-BT50 Room Temp S7",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep46-bt50-room-temp-s7-40168"
#   },
#   "40169": {
#     "title": "EP45-BT50 Room Temp S6",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep45-bt50-room-temp-s6-40169"
#   },
#   "40170": {
#     "title": "EP44-BT50 Room Temp S5",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep44-bt50-room-temp-s5-40170"
#   },
#   "40183": {
#     "title": "AZ30-BT23 Outdoor temp. ERS 1",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az30-bt23-outdoor-temp-ers-1-40183"
#   },
#   "40185": {
#     "title": "BT1 Average, 1h",
#     "info": "EB100-BT1 Outdoor temperature average, 1h",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt1-average-1h-40185"
#   },
#   "40188": {
#     "title": "EP47-BT50 Room Temp S8 Average",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep47-bt50-room-temp-s8-average-40188"
#   },
#   "40189": {
#     "title": "EP46-BT50 Room Temp S7 Average",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep46-bt50-room-temp-s7-average-40189"
#   },
#   "40190": {
#     "title": "EP45-BT50 Room Temp S6 Average",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep45-bt50-room-temp-s6-average-40190"
#   },
#   "40191": {
#     "title": "EP44-BT50 Room Temp S5 Average",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep44-bt50-room-temp-s5-average-40191"
#   },
#   "40192": {
#     "title": "EP23-BT50 Room Temp S4 Average",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep23-bt50-room-temp-s4-average-40192"
#   },
#   "40193": {
#     "title": "EP22-BT50 Room Temp S3 Average",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep22-bt50-room-temp-s3-average-40193"
#   },
#   "40194": {
#     "title": "EP21-BT50 Room Temp S2 Average",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep21-bt50-room-temp-s2-average-40194"
#   },
#   "40195": {
#     "title": "BT50 Room Temp S1 Average",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt50-room-temp-s1-average-40195"
#   },
#   "40212": {
#     "title": "BT74 Average",
#     "info": "BT74 heating cooling sensor average",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt74-average-40212"
#   },
#   "40216": {
#     "title": "BT25 Ext. supply temp, cooling",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt25-ext-supply-temp-cooling-40216"
#   },
#   "40217": {
#     "title": "Calc. Supply S8",
#     "info": "Calculated supply temperature for the climate system",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "calc-supply-s8-40217"
#   },
#   "40218": {
#     "title": "Calc. Supply S7",
#     "info": "Calculated supply temperature for the climate system",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "calc-supply-s7-40218"
#   },
#   "40219": {
#     "title": "Calc. Supply S6",
#     "info": "Calculated supply temperature for the climate system",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "calc-supply-s6-40219"
#   },
#   "40220": {
#     "title": "Calculated Supply S5",
#     "info": "Calculated supply temperature for the climate system",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "calculated-supply-s5-40220"
#   },
#   "40221": {
#     "title": "Calc. Cooling Supply S8",
#     "info": "Calculated supply temperature in cooling mode for the climate system",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "calc-cooling-supply-s8-40221"
#   },
#   "40222": {
#     "title": "Calc. Cooling Supply S7",
#     "info": "Calculated supply temperature in cooling mode for the climate system",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "calc-cooling-supply-s7-40222"
#   },
#   "40223": {
#     "title": "Calc. Cooling Supply S6",
#     "info": "Calculated supply temperature in cooling mode for the climate system",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "calc-cooling-supply-s6-40223"
#   },
#   "40224": {
#     "title": "Calc. Cooling Supply S5",
#     "info": "Calculated supply temperature in cooling mode for the climate system",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "calc-cooling-supply-s5-40224"
#   },
#   "40305": {
#     "title": "Mixing Valve State S8",
#     "info": "State of the mixing valve for the climate system",
#     "size": "u8",
#     "factor": 1,
#     "name": "mixing-valve-state-s8-40305"
#   },
#   "40306": {
#     "title": "Mixing Valve State S7",
#     "info": "State of the mixing valve for the climate system",
#     "size": "u8",
#     "factor": 1,
#     "name": "mixing-valve-state-s7-40306"
#   },
#   "40307": {
#     "title": "Mixing Valve State S6",
#     "info": "State of the mixing valve for the climate system",
#     "size": "u8",
#     "factor": 1,
#     "name": "mixing-valve-state-s6-40307"
#   },
#   "40308": {
#     "title": "Mixing Valve State S5",
#     "info": "State of the mixing valve for the climate system",
#     "size": "u8",
#     "factor": 1,
#     "name": "mixing-valve-state-s5-40308"
#   },
#   "40310": {
#     "title": "External ERS 1 accessory relays",
#     "info": "Indicates the status of the relays on the ERS accessory. The information is binary encoded. b0: K1, b1: K2, b2: K3, b3: K4",
#     "size": "u8",
#     "factor": 1,
#     "name": "external-ers-1-accessory-relays-40310"
#   },
#   "40311": {
#     "title": "External ERS 1 accessory GQ2 speed",
#     "info": "Indicates the speed of the GQ2 fan speed on the ERS accessory.",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "external-ers-1-accessory-gq2-speed-40311"
#   },
#   "40312": {
#     "title": "External ERS 1 accessory GQ3 speed",
#     "info": "Indicates the speed of the GQ3 fan speed on the ERS accessory.",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "external-ers-1-accessory-gq3-speed-40312"
#   },
#   "40316": {
#     "title": "Inverter limit status",
#     "size": "u8",
#     "factor": 1,
#     "name": "inverter-limit-status-40316"
#   },
#   "40317": {
#     "title": "Inverter drive status",
#     "size": "u16",
#     "factor": 1,
#     "name": "inverter-drive-status-40317"
#   },
#   "40321": {
#     "title": "Compressor Frequency, Request",
#     "info": "The compressor frequency that has been requested by the system",
#     "unit": "Hz",
#     "size": "u16",
#     "factor": 1,
#     "name": "compressor-frequency-request-40321"
#   },
#   "40322": {
#     "title": "Max Compressor Frequency, Heating",
#     "info": "The maximum frequency of the compressor in heating mode",
#     "unit": "Hz",
#     "size": "u16",
#     "factor": 100,
#     "name": "max-compressor-frequency-heating-40322"
#   },
#   "40323": {
#     "title": "Inverter alarm code",
#     "size": "u16",
#     "factor": 1,
#     "name": "inverter-alarm-code-40323"
#   },
#   "40324": {
#     "title": "Inverter fault code",
#     "size": "u16",
#     "factor": 1,
#     "name": "inverter-fault-code-40324"
#   },
#   "40326": {
#     "title": "Inverter drive command",
#     "size": "u16",
#     "factor": 1,
#     "name": "inverter-drive-command-40326"
#   },
#   "40327": {
#     "title": "NIBE Inverter Pic version",
#     "size": "u16",
#     "factor": 1,
#     "name": "nibe-inverter-pic-version-40327"
#   },
#   "40328": {
#     "title": "NIBE Inverter 8051 version",
#     "size": "u16",
#     "factor": 1,
#     "name": "nibe-inverter-8051-version-40328"
#   },
#   "40329": {
#     "title": "NIBE Inverter Def. Wizard",
#     "size": "u16",
#     "factor": 1,
#     "name": "nibe-inverter-def-wizard-40329"
#   },
#   "40330": {
#     "title": "NIBE Inverter Mce version",
#     "size": "u16",
#     "factor": 1,
#     "name": "nibe-inverter-mce-version-40330"
#   },
#   "40331": {
#     "title": "NIBE Inverter Hw version",
#     "size": "u16",
#     "factor": 1,
#     "name": "nibe-inverter-hw-version-40331"
#   },
#   "40332": {
#     "title": "NIBE Inverter Hw type",
#     "size": "u16",
#     "factor": 1,
#     "name": "nibe-inverter-hw-type-40332"
#   },
#   "40339": {
#     "title": "External adjustment activated via input S8",
#     "size": "u8",
#     "factor": 1,
#     "name": "external-adjustment-activated-via-input-s8-40339"
#   },
#   "40340": {
#     "title": "External adjustment activated via input S7",
#     "size": "u8",
#     "factor": 1,
#     "name": "external-adjustment-activated-via-input-s7-40340"
#   },
#   "40341": {
#     "title": "External adjustment activated via input S6",
#     "size": "u8",
#     "factor": 1,
#     "name": "external-adjustment-activated-via-input-s6-40341"
#   },
#   "40342": {
#     "title": "External adjustment activated via input S5",
#     "size": "u8",
#     "factor": 1,
#     "name": "external-adjustment-activated-via-input-s5-40342"
#   },
#   "40365": {
#     "title": "Extra heating system pump S8",
#     "size": "u8",
#     "factor": 1,
#     "name": "extra-heating-system-pump-s8-40365"
#   },
#   "40366": {
#     "title": "Extra heating system pump S7",
#     "size": "u8",
#     "factor": 1,
#     "name": "extra-heating-system-pump-s7-40366"
#   },
#   "40367": {
#     "title": "Extra heating system pump S6",
#     "size": "u8",
#     "factor": 1,
#     "name": "extra-heating-system-pump-s6-40367"
#   },
#   "40368": {
#     "title": "Extra heating system pump S5",
#     "size": "u8",
#     "factor": 1,
#     "name": "extra-heating-system-pump-s5-40368"
#   },
#   "40369": {
#     "title": "Extra cooling HPAC, ACS",
#     "size": "u8",
#     "factor": 1,
#     "name": "extra-cooling-hpac-acs-40369"
#   },
#   "40625": {
#     "title": "BT82 HW Comfort Return Temp",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt82-hw-comfort-return-temp-40625"
#   },
#   "40626": {
#     "title": "BT83 HW Comfort Cylinder Temp",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt83-hw-comfort-cylinder-temp-40626"
#   },
#   "40755": {
#     "title": "Tot. ext. HW add op.time",
#     "info": "Total external hw-electric additive operation time",
#     "unit": "h",
#     "size": "s32",
#     "factor": 10,
#     "min": 0.0,
#     "max": 9999999.0,
#     "default": 0.0,
#     "name": "tot-ext-hw-add-op-time-40755"
#   },
#   "40771": {
#     "title": "Heat Meter - Pool2 Cpr EP14",
#     "info": "Accumulated energy production as calculated by the heat meter",
#     "unit": "kWh",
#     "size": "u32",
#     "factor": 10,
#     "name": "heat-meter-pool2-cpr-ep14-40771"
#   },
#   "40792": {
#     "title": "OPT state",
#     "info": "Indicates the state of the boiler connected through the OPT accessory.",
#     "size": "u8",
#     "factor": 1,
#     "name": "opt-state-40792"
#   },
#   "40793": {
#     "title": "OPT version",
#     "info": "Version of the OPT PCBA software",
#     "size": "u16",
#     "factor": 1,
#     "name": "opt-version-40793"
#   },
#   "40801": {
#     "title": "OPT rel. modulation level",
#     "info": "OPT relative modulation level",
#     "unit": "%",
#     "size": "s16",
#     "factor": 10,
#     "name": "opt-rel-modulation-level-40801"
#   },
#   "40802": {
#     "title": "OPT boiler temperature",
#     "info": "OPT boiler temperature",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "opt-boiler-temperature-40802"
#   },
#   "40806": {
#     "title": "OPT boiler op. time",
#     "info": "OPT boiler operation time",
#     "unit": "h",
#     "size": "u16",
#     "factor": 1,
#     "name": "opt-boiler-op-time-40806"
#   },
#   "40813": {
#     "title": "Compressor slow down reason",
#     "info": "Bitmap telling the reason to why the compressor slows down. b0:inverter b1:brine b2:current b3:high cond b4:hot gas b5:evaporator",
#     "size": "u8",
#     "factor": 1,
#     "name": "compressor-slow-down-reason-40813"
#   },
#   "40834": {
#     "title": "BM1 Humidity ",
#     "unit": "%",
#     "size": "s16",
#     "factor": 10,
#     "name": "bm1-humidity-40834"
#   },
#   "40856": {
#     "title": "BM1 BT50 Room temp.",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bm1-bt50-room-temp-40856"
#   },
#   "40857": {
#     "title": "BM1 Pressure ",
#     "unit": "kPa",
#     "size": "s16",
#     "factor": 10,
#     "name": "bm1-pressure-40857"
#   },
#   "40858": {
#     "title": "BM1 Dewpoint",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bm1-dewpoint-40858"
#   },
#   "40868": {
#     "title": "+Adjust AUX Port",
#     "unit": "1",
#     "size": "u8",
#     "factor": 1,
#     "name": "adjust-aux-port-40868"
#   },
#   "40870": {
#     "title": "+Adjust OP mode",
#     "info": "Tells if plusadjust system calls for heat or cool",
#     "size": "u8",
#     "factor": 1,
#     "name": "adjust-op-mode-40870"
#   },
#   "40871": {
#     "title": "+Adjust Comfort mode",
#     "info": "Which comfort mode",
#     "size": "u8",
#     "factor": 1,
#     "name": "adjust-comfort-mode-40871"
#   },
#   "40872": {
#     "title": "+Adjust Parallell adjustment",
#     "info": "requested adjustment",
#     "size": "s8",
#     "factor": 1,
#     "name": "adjust-parallell-adjustment-40872"
#   },
#   "40873": {
#     "title": "+Adjust Humidity",
#     "info": "Humidity",
#     "unit": "%RH",
#     "size": "s16",
#     "factor": 10,
#     "name": "adjust-humidity-40873"
#   },
#   "40874": {
#     "title": "+Adjust Temp indoor",
#     "info": "Average of all room sensors",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "adjust-temp-indoor-40874"
#   },
#   "40875": {
#     "title": "+Adjust Temp outdoor",
#     "info": "Outdoor temp",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "adjust-temp-outdoor-40875"
#   },
#   "40876": {
#     "title": "+Adjust Version",
#     "info": "PCA input version",
#     "size": "u16",
#     "factor": 1,
#     "name": "adjust-version-40876"
#   },
#   "40877": {
#     "title": "+Adjust Activated",
#     "info": "If plusadjust accessory is activated",
#     "size": "u8",
#     "factor": 1,
#     "name": "adjust-activated-40877"
#   },
#   "40878": {
#     "title": "+Adjust Need",
#     "info": "If plusadjust system calls for heat",
#     "size": "u8",
#     "factor": 1,
#     "name": "adjust-need-40878"
#   },
#   "40889": {
#     "title": "BT64 Average",
#     "info": "BT64 Cooling supply average",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "bt64-average-40889"
#   },
#   "40912": {
#     "title": "EQ1 State ACS Thermostat",
#     "info": "10=off,40=active wait,50=active",
#     "size": "u8",
#     "factor": 1,
#     "name": "eq1-state-acs-thermostat-40912",
#     "mappings": {
#       "10": "off",
#       "40": "active wait",
#       "50": "active"
#     }
#   },
#   "40913": {
#     "title": "EQ1 State ACS Thermostat Heat Dump",
#     "info": "10=shunt off,20=shunt open,30=shunt closed",
#     "size": "u8",
#     "factor": 1,
#     "name": "eq1-state-acs-thermostat-heat-dump-40913",
#     "mappings": {
#       "10": "shunt off",
#       "20": "shunt open",
#       "30": "shunt closed"
#     }
#   },
#   "40940": {
#     "title": "Degree Minutes (32 bit)",
#     "info": "Degree minutes, 32bit value. Full resolution.",
#     "size": "s32",
#     "factor": 10,
#     "min": -30000.0,
#     "max": 30000.0,
#     "default": 0.0,
#     "name": "degree-minutes-32-bit-40940",
#     "write": true
#   },
#   "40942": {
#     "title": "External ERS 1 accessory block status",
#     "info": "Indicates if the ERS accessory is externaly blocked.",
#     "size": "u8",
#     "factor": 1,
#     "name": "external-ers-1-accessory-block-status-40942"
#   },
#   "40943": {
#     "title": "External ERS 1 accessory EB17",
#     "info": "Indicates if the status of ERS accessory EB17. I = closed, 0 = open.",
#     "size": "u8",
#     "factor": 1,
#     "name": "external-ers-1-accessory-eb17-40943",
#     "mappings": {
#       "1": "closed",
#       "0": "open"
#     }
#   },
#   "40993": {
#     "title": "Inverter min speed",
#     "size": "u16",
#     "factor": 1,
#     "name": "inverter-min-speed-40993"
#   },
#   "40994": {
#     "title": "Inverter max speed",
#     "size": "u16",
#     "factor": 1,
#     "name": "inverter-max-speed-40994"
#   },
#   "40995": {
#     "title": "External Energy Meter 2 Accumulated Energy",
#     "unit": "kWh",
#     "size": "u32",
#     "factor": 100,
#     "min": 0.0,
#     "max": 2147483647.0,
#     "default": 0.0,
#     "name": "external-energy-meter-2-accumulated-energy-40995"
#   },
#   "40997": {
#     "title": "External Energy Meter 1 Accumulated Energy",
#     "unit": "kWh",
#     "size": "u32",
#     "factor": 100,
#     "min": 0.0,
#     "max": 2147483647.0,
#     "default": 0.0,
#     "name": "external-energy-meter-1-accumulated-energy-40997"
#   },
#   "41027": {
#     "title": "Humidity average",
#     "info": "Humidity average",
#     "unit": "%",
#     "size": "s16",
#     "factor": 10,
#     "name": "humidity-average-41027"
#   },
#   "41186": {
#     "title": "Set point OPT boiler",
#     "info": "Set point OPT boiler",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "set-point-opt-boiler-41186"
#   },
#   "41189": {
#     "title": "AA20-BE5 EME10 Current",
#     "unit": "A",
#     "size": "s16",
#     "factor": 10,
#     "name": "aa20-be5-eme10-current-41189"
#   },
#   "41190": {
#     "title": "AA20-BE5 EME10 Average Current",
#     "unit": "A",
#     "size": "s16",
#     "factor": 10,
#     "name": "aa20-be5-eme10-average-current-41190"
#   },
#   "41191": {
#     "title": "PV Panel State",
#     "size": "u8",
#     "factor": 1,
#     "name": "pv-panel-state-41191"
#   },
#   "41210": {
#     "title": "AZ4-BT50 Room temp",
#     "info": "AZ4-BT50 Room temp",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az4-bt50-room-temp-41210"
#   },
#   "41211": {
#     "title": "AZ3-BT50 Room temp",
#     "info": "AZ3-BT50 Room temp",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az3-bt50-room-temp-41211"
#   },
#   "41212": {
#     "title": "AZ2-BT50 Room temp",
#     "info": "AZ2-BT50 Room temp",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az2-bt50-room-temp-41212"
#   },
#   "41213": {
#     "title": "AZ1-BT50 Room temp",
#     "info": "AZ1-BT50 Room temp",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "az1-bt50-room-temp-41213"
#   },
#   "41256": {
#     "title": "Fan speed current",
#     "info": "The current fan speed after scheduling and blocks are considered",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "fan-speed-current-41256"
#   },
#   "41257": {
#     "title": "Fan speed current",
#     "info": "The current fan speed after scheduling and blocks are considered",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "fan-speed-current-41257"
#   },
#   "41258": {
#     "title": "Fan speed current",
#     "info": "The current fan speed after scheduling and blocks are considered",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "fan-speed-current-41258"
#   },
#   "41265": {
#     "title": "Smart Home Mode",
#     "info": "Current smart home mode, 0=Default,1=Away from home,2=Vacation",
#     "size": "u8",
#     "factor": 1,
#     "name": "smart-home-mode-41265",
#     "mappings": {
#       "0": "Default",
#       "1": "Away from home",
#       "2": "Vacation"
#     }
#   },
#   "41266": {
#     "title": "Offset to smart home system",
#     "info": "Offset to smart home system",
#     "unit": "\u00b0C",
#     "size": "s8",
#     "factor": 10,
#     "name": "offset-to-smart-home-system-41266"
#   },
#   "41267": {
#     "title": "Smart Home ctrl syst 8",
#     "info": "Smart Home is controlling the system",
#     "size": "u8",
#     "factor": 1,
#     "name": "smart-home-ctrl-syst-8-41267"
#   },
#   "41268": {
#     "title": "Smart Home ctrl syst 7",
#     "info": "Smart Home is controlling the system",
#     "size": "u8",
#     "factor": 1,
#     "name": "smart-home-ctrl-syst-7-41268"
#   },
#   "41269": {
#     "title": "Smart Home ctrl syst 6",
#     "info": "Smart Home is controlling the system",
#     "size": "u8",
#     "factor": 1,
#     "name": "smart-home-ctrl-syst-6-41269"
#   },
#   "41270": {
#     "title": "Smart Home ctrl syst 5",
#     "info": "Smart Home is controlling the system",
#     "size": "u8",
#     "factor": 1,
#     "name": "smart-home-ctrl-syst-5-41270"
#   },
#   "41271": {
#     "title": "Smart Home ctrl syst 4",
#     "info": "Smart Home is controlling the system",
#     "size": "u8",
#     "factor": 1,
#     "name": "smart-home-ctrl-syst-4-41271"
#   },
#   "41272": {
#     "title": "Smart Home ctrl syst 3",
#     "info": "Smart Home is controlling the system",
#     "size": "u8",
#     "factor": 1,
#     "name": "smart-home-ctrl-syst-3-41272"
#   },
#   "41273": {
#     "title": "Smart Home ctrl syst 2",
#     "info": "Smart Home is controlling the system",
#     "size": "u8",
#     "factor": 1,
#     "name": "smart-home-ctrl-syst-2-41273"
#   },
#   "41274": {
#     "title": "Smart Home ctrl syst 1",
#     "info": "Smart Home is controlling the system",
#     "size": "u8",
#     "factor": 1,
#     "name": "smart-home-ctrl-syst-1-41274"
#   },
#   "41287": {
#     "title": "OPT boiler has priority hot water",
#     "info": "OPT boiler has priority hot water",
#     "size": "u8",
#     "factor": 1,
#     "name": "opt-boiler-has-priority-hot-water-41287"
#   },
#   "41393": {
#     "title": "Smart energy source, energy source prio 7, start DM",
#     "info": "Energy source prio 7, start DM",
#     "size": "s32",
#     "factor": 1,
#     "name": "smart-energy-source-energy-source-prio-7-start-dm-41393"
#   },
#   "41395": {
#     "title": "Smart energy source, energy source prio 6, start DM",
#     "info": "Energy source prio 6, start DM",
#     "size": "s32",
#     "factor": 1,
#     "name": "smart-energy-source-energy-source-prio-6-start-dm-41395"
#   },
#   "41397": {
#     "title": "Smart energy source, energy source prio 5, start DM",
#     "info": "Energy source prio 5, start DM",
#     "size": "s32",
#     "factor": 1,
#     "name": "smart-energy-source-energy-source-prio-5-start-dm-41397"
#   },
#   "41399": {
#     "title": "Smart energy source, energy source prio 4, start DM",
#     "info": "Energy source prio 4, start DM",
#     "size": "s32",
#     "factor": 1,
#     "name": "smart-energy-source-energy-source-prio-4-start-dm-41399"
#   },
#   "41401": {
#     "title": "Smart energy source, energy source prio 3, start DM",
#     "info": "Energy source prio 3, start DM",
#     "size": "s32",
#     "factor": 1,
#     "name": "smart-energy-source-energy-source-prio-3-start-dm-41401"
#   },
#   "41403": {
#     "title": "Smart energy source, energy source prio 2, start DM",
#     "info": "Energy source prio 2, start DM",
#     "size": "s32",
#     "factor": 1,
#     "name": "smart-energy-source-energy-source-prio-2-start-dm-41403"
#   },
#   "41405": {
#     "title": "Smart energy source, energy source prio 1, start DM",
#     "info": "Energy source prio 1, start DM",
#     "size": "s32",
#     "factor": 1,
#     "name": "smart-energy-source-energy-source-prio-1-start-dm-41405"
#   },
#   "41421": {
#     "title": "Smart energy source, degree minute min value",
#     "info": "Smart energy source, degree minute min value in Smart energy source system",
#     "size": "s32",
#     "factor": 1,
#     "name": "smart-energy-source-degree-minute-min-value-41421"
#   },
#   "41424": {
#     "title": "Smart energy source, actual OPT10 addition price",
#     "info": "Smart energy source, actual OPT10 addition price.",
#     "size": "u16",
#     "factor": 1,
#     "name": "smart-energy-source-actual-opt10-addition-price-41424"
#   },
#   "41425": {
#     "title": "Smart energy source, actual shunt add price",
#     "info": "Smart energy source, actual external step addition price.",
#     "size": "u16",
#     "factor": 1,
#     "name": "smart-energy-source-actual-shunt-add-price-41425"
#   },
#   "41426": {
#     "title": "Smart energy source, actual ext. step add price",
#     "info": "Smart energy source, actual external step add price.",
#     "size": "u16",
#     "factor": 1,
#     "name": "smart-energy-source-actual-ext-step-add-price-41426"
#   },
#   "41427": {
#     "title": "Smart energy source, actual electricity price",
#     "info": "Smart energy source, actual electricity price.",
#     "size": "u16",
#     "factor": 1,
#     "name": "smart-energy-source-actual-electricity-price-41427"
#   },
#   "41429": {
#     "title": "EP12-BT57 Collector In",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep12-bt57-collector-in-41429"
#   },
#   "41430": {
#     "title": "EP12-BT58 Collector Out",
#     "unit": "\u00b0C",
#     "size": "s16",
#     "factor": 10,
#     "name": "ep12-bt58-collector-out-41430"
#   },
#   "41928": {
#     "title": "Smart Price Adaption Price",
#     "info": "The current electric price",
#     "size": "u16",
#     "factor": 100,
#     "name": "smart-price-adaption-price-41928"
#   },
#   "41929": {
#     "title": "Smart Price Adaption Price Level",
#     "info": "Whether the current price is unknown (0), low (1), medium (2), high (3)",
#     "size": "u8",
#     "factor": 1,
#     "name": "smart-price-adaption-price-level-41929"
#   },
#   "41930": {
#     "title": "AA23-BE5 Power 10",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-power-10-41930"
#   },
#   "41931": {
#     "title": "AA23-BE5 Power 9",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-power-9-41931"
#   },
#   "41932": {
#     "title": "AA23-BE5 Power 8",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-power-8-41932"
#   },
#   "41933": {
#     "title": "AA23-BE5 Power 7",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-power-7-41933"
#   },
#   "41934": {
#     "title": "AA23-BE5 Power 6",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-power-6-41934"
#   },
#   "41935": {
#     "title": "AA23-BE5 Power 5",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-power-5-41935"
#   },
#   "41936": {
#     "title": "AA23-BE5 Power 4",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-power-4-41936"
#   },
#   "41937": {
#     "title": "AA23-BE5 Power 3",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-power-3-41937"
#   },
#   "41938": {
#     "title": "AA23-BE5 Power 2",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-power-2-41938"
#   },
#   "41939": {
#     "title": "AA23-BE5 Power 1",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-power-1-41939"
#   },
#   "41940": {
#     "title": "AA23-BE5 Error High 10",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-high-10-41940"
#   },
#   "41941": {
#     "title": "AA23-BE5 Error High 9",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-high-9-41941"
#   },
#   "41942": {
#     "title": "AA23-BE5 Error High 8",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-high-8-41942"
#   },
#   "41943": {
#     "title": "AA23-BE5 Error High 7",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-high-7-41943"
#   },
#   "41944": {
#     "title": "AA23-BE5 Error High 6",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-high-6-41944"
#   },
#   "41945": {
#     "title": "AA23-BE5 Error High 5",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-high-5-41945"
#   },
#   "41946": {
#     "title": "AA23-BE5 Error High 4",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-high-4-41946"
#   },
#   "41947": {
#     "title": "AA23-BE5 Error High 3",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-high-3-41947"
#   },
#   "41948": {
#     "title": "AA23-BE5 Error High 2",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-high-2-41948"
#   },
#   "41949": {
#     "title": "AA23-BE5 Error High 1",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-high-1-41949"
#   },
#   "41950": {
#     "title": "AA23-BE5 Error Low 10",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-low-10-41950"
#   },
#   "41951": {
#     "title": "AA23-BE5 Error Low 9",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-low-9-41951"
#   },
#   "41952": {
#     "title": "AA23-BE5 Error Low 8",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-low-8-41952"
#   },
#   "41953": {
#     "title": "AA23-BE5 Error Low 7",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-low-7-41953"
#   },
#   "41954": {
#     "title": "AA23-BE5 Error Low 6",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-low-6-41954"
#   },
#   "41955": {
#     "title": "AA23-BE5 Error Low 5",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-low-5-41955"
#   },
#   "41956": {
#     "title": "AA23-BE5 Error Low 4",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-low-4-41956"
#   },
#   "41957": {
#     "title": "AA23-BE5 Error Low 3",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-low-3-41957"
#   },
#   "41958": {
#     "title": "AA23-BE5 Error Low 2",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-low-2-41958"
#   },
#   "41959": {
#     "title": "AA23-BE5 Error Low 1",
#     "unit": "W",
#     "size": "u16",
#     "factor": 1,
#     "name": "aa23-be5-error-low-1-41959"
#   },
#   "41960": {
#     "title": "AA23-BE5 Com Percentage 10",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "aa23-be5-com-percentage-10-41960"
#   },
#   "41961": {
#     "title": "AA23-BE5 Com Percentage 9",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "aa23-be5-com-percentage-9-41961"
#   },
#   "41962": {
#     "title": "AA23-BE5 Com Percentage 8",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "aa23-be5-com-percentage-8-41962"
#   },
#   "41963": {
#     "title": "AA23-BE5 Com Percentage 7",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "aa23-be5-com-percentage-7-41963"
#   },
#   "41964": {
#     "title": "AA23-BE5 Com Percentage 6",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "aa23-be5-com-percentage-6-41964"
#   },
#   "41965": {
#     "title": "AA23-BE5 Com Percentage 5",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "aa23-be5-com-percentage-5-41965"
#   },
#   "41966": {
#     "title": "AA23-BE5 Com Percentage 4",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "aa23-be5-com-percentage-4-41966"
#   },
#   "41967": {
#     "title": "AA23-BE5 Com Percentage 3",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "aa23-be5-com-percentage-3-41967"
#   },
#   "41968": {
#     "title": "AA23-BE5 Com Percentage 2",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "aa23-be5-com-percentage-2-41968"
#   },
#   "41969": {
#     "title": "AA23-BE5 Com Percentage 1",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "name": "aa23-be5-com-percentage-1-41969"
#   },
#   "41980": {
#     "title": "AA23-BE5 Voltage1 10",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage1-10-41980"
#   },
#   "41981": {
#     "title": "AA23-BE5 Voltage1 9",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage1-9-41981"
#   },
#   "41982": {
#     "title": "AA23-BE5 Voltage1 8",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage1-8-41982"
#   },
#   "41983": {
#     "title": "AA23-BE5 Voltage1 7",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage1-7-41983"
#   },
#   "41984": {
#     "title": "AA23-BE5 Voltage1 6",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage1-6-41984"
#   },
#   "41985": {
#     "title": "AA23-BE5 Voltage1 5",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage1-5-41985"
#   },
#   "41986": {
#     "title": "AA23-BE5 Voltage1 4",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage1-4-41986"
#   },
#   "41987": {
#     "title": "AA23-BE5 Voltage1 3",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage1-3-41987"
#   },
#   "41988": {
#     "title": "AA23-BE5 Voltage1 2",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage1-2-41988"
#   },
#   "41989": {
#     "title": "AA23-BE5 Voltage1 1",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage1-1-41989"
#   },
#   "41990": {
#     "title": "AA23-BE5 Voltage2 10",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage2-10-41990"
#   },
#   "41991": {
#     "title": "AA23-BE5 Voltage2 9",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage2-9-41991"
#   },
#   "41992": {
#     "title": "AA23-BE5 Voltage2 8",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage2-8-41992"
#   },
#   "41993": {
#     "title": "AA23-BE5 Voltage2 7",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage2-7-41993"
#   },
#   "41994": {
#     "title": "AA23-BE5 Voltage2 6",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage2-6-41994"
#   },
#   "41995": {
#     "title": "AA23-BE5 Voltage2 5",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage2-5-41995"
#   },
#   "41996": {
#     "title": "AA23-BE5 Voltage2 4",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage2-4-41996"
#   },
#   "41997": {
#     "title": "AA23-BE5 Voltage2 3",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage2-3-41997"
#   },
#   "41998": {
#     "title": "AA23-BE5 Voltage2 2",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage2-2-41998"
#   },
#   "41999": {
#     "title": "AA23-BE5 Voltage2 1",
#     "unit": "V",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-voltage2-1-41999"
#   },
#   "42000": {
#     "title": "AA23-BE5 Temperature 10",
#     "unit": "\u00b0C",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-temperature-10-42000"
#   },
#   "42001": {
#     "title": "AA23-BE5 Temperature 9",
#     "unit": "\u00b0C",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-temperature-9-42001"
#   },
#   "42002": {
#     "title": "AA23-BE5 Temperature 8",
#     "unit": "\u00b0C",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-temperature-8-42002"
#   },
#   "42003": {
#     "title": "AA23-BE5 Temperature 7",
#     "unit": "\u00b0C",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-temperature-7-42003"
#   },
#   "42004": {
#     "title": "AA23-BE5 Temperature 6",
#     "unit": "\u00b0C",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-temperature-6-42004"
#   },
#   "42005": {
#     "title": "AA23-BE5 Temperature 5",
#     "unit": "\u00b0C",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-temperature-5-42005"
#   },
#   "42006": {
#     "title": "AA23-BE5 Temperature 4",
#     "unit": "\u00b0C",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-temperature-4-42006"
#   },
#   "42007": {
#     "title": "AA23-BE5 Temperature 3",
#     "unit": "\u00b0C",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-temperature-3-42007"
#   },
#   "42008": {
#     "title": "AA23-BE5 Temperature 2",
#     "unit": "\u00b0C",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-temperature-2-42008"
#   },
#   "42009": {
#     "title": "AA23-BE5 Temperature 1",
#     "unit": "\u00b0C",
#     "size": "u16",
#     "factor": 10,
#     "name": "aa23-be5-temperature-1-42009"
#   },
#   "42010": {
#     "title": "AA23-BE5 Energy 10",
#     "unit": "kWh",
#     "size": "u32",
# ...
#     "info": "Energy meter X23 in mode Wh/pulse = 0 or pulses/kWh = 1",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "energy-meter-mode-x23-49287",
#     "write": true
#   },
#   "49288": {
#     "title": "Energy Meter mode X22",
#     "info": "Energy meter X22 in mode Wh/pulse = 0 or pulses/kWh = 1",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "energy-meter-mode-x22-49288",
#     "write": true
#   },
#   "49289": {
#     "title": "Ground water pump speed control ",
#     "info": " ",
#     "size": "s8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "ground-water-pump-speed-control-49289",
#     "write": true
#   },
#   "49290": {
#     "title": "Ground water pump auto speed control",
#     "info": "Ground water pump auto speed control",
#     "size": "s8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 1.0,
#     "name": "ground-water-pump-auto-speed-control-49290",
#     "write": true
#   },
#   "49291": {
#     "title": "Ground water pump manual speed",
#     "info": "Ground water pump temperature alarm level",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 1.0,
#     "max": 100.0,
#     "default": 75.0,
#     "name": "ground-water-pump-manual-speed-49291",
#     "write": true
#   },
#   "49292": {
#     "title": "Ground water pump control signal",
#     "info": "Ground water pump control signal (0 = 0V-10V; 1= 10V-0V)",
#     "size": "s8",
#     "factor": 1,
#     "name": "ground-water-pump-control-signal-49292",
#     "write": true,
#     "mappings": {
#       "0": "0V-10V",
#       "1": "10V-0V"
#     }
#   },
#   "49293": {
#     "title": "Ground water pump min speed",
#     "info": "Ground water pump voltage at min speed",
#     "unit": "V",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 80.0,
#     "default": 30.0,
#     "name": "ground-water-pump-min-speed-49293",
#     "write": true
#   },
#   "49297": {
#     "title": "EME20 Activated",
#     "info": "0=not activated, 1=activated",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "eme20-activated-49297",
#     "write": true
#   },
#   "49298": {
#     "title": "EME PV Panel Affect Pool",
#     "info": "0=not affecting, 1=affecting",
#     "size": "u8",
#     "factor": 1,
#     "name": "eme-pv-panel-affect-pool-49298",
#     "write": true
#   },
#   "49328": {
#     "title": "ERS 4 Exhaust Fan speed 4",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 100.0,
#     "name": "ers-4-exhaust-fan-speed-4-49328",
#     "write": true
#   },
#   "49329": {
#     "title": "ERS 3 Exhaust Fan speed 4",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 100.0,
#     "name": "ers-3-exhaust-fan-speed-4-49329",
#     "write": true
#   },
#   "49330": {
#     "title": "ERS 2 Exhaust Fan speed 4",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 100.0,
#     "name": "ers-2-exhaust-fan-speed-4-49330",
#     "write": true
#   },
#   "49331": {
#     "title": "ERS 4 Exhaust Fan speed 3",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 80.0,
#     "name": "ers-4-exhaust-fan-speed-3-49331",
#     "write": true
#   },
#   "49332": {
#     "title": "ERS 3 Exhaust Fan speed 3",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 80.0,
#     "name": "ers-3-exhaust-fan-speed-3-49332",
#     "write": true
#   },
#   "49333": {
#     "title": "ERS 2 Exhaust Fan speed 3",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 80.0,
#     "name": "ers-2-exhaust-fan-speed-3-49333",
#     "write": true
#   },
#   "49334": {
#     "title": "ERS 4 Exhaust Fan speed 2",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 30.0,
#     "name": "ers-4-exhaust-fan-speed-2-49334",
#     "write": true
#   },
#   "49335": {
#     "title": "ERS 3 Exhaust Fan speed 2",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 30.0,
#     "name": "ers-3-exhaust-fan-speed-2-49335",
#     "write": true
#   },
#   "49336": {
#     "title": "ERS 2 Exhaust Fan speed 2",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 30.0,
#     "name": "ers-2-exhaust-fan-speed-2-49336",
#     "write": true
#   },
#   "49337": {
#     "title": "ERS 4 Exhaust Fan speed 1",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 0.0,
#     "name": "ers-4-exhaust-fan-speed-1-49337",
#     "write": true
#   },
#   "49338": {
#     "title": "ERS 3 Exhaust Fan speed 1",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 0.0,
#     "name": "ers-3-exhaust-fan-speed-1-49338",
#     "write": true
#   },
#   "49339": {
#     "title": "ERS 2 Exhaust Fan speed 1",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 0.0,
#     "name": "ers-2-exhaust-fan-speed-1-49339",
#     "write": true
#   },
#   "49340": {
#     "title": "ERS 4 Exhaust Fan speed normal",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 1.0,
#     "max": 100.0,
#     "default": 75.0,
#     "name": "ers-4-exhaust-fan-speed-normal-49340",
#     "write": true
#   },
#   "49341": {
#     "title": "ERS 3 Exhaust Fan speed normal",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 1.0,
#     "max": 100.0,
#     "default": 75.0,
#     "name": "ers-3-exhaust-fan-speed-normal-49341",
#     "write": true
#   },
#   "49342": {
#     "title": "ERS 2 Exhaust Fan speed normal",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 1.0,
#     "max": 100.0,
#     "default": 75.0,
#     "name": "ers-2-exhaust-fan-speed-normal-49342",
#     "write": true
#   },
#   "49343": {
#     "title": "ERS 4 Supply Fan speed 4",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 100.0,
#     "name": "ers-4-supply-fan-speed-4-49343",
#     "write": true
#   },
#   "49344": {
#     "title": "ERS 3 Supply Fan speed 4",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 100.0,
#     "name": "ers-3-supply-fan-speed-4-49344",
#     "write": true
#   },
#   "49345": {
#     "title": "ERS 2 Supply Fan speed 4",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 100.0,
#     "name": "ers-2-supply-fan-speed-4-49345",
#     "write": true
#   },
#   "49346": {
#     "title": "ERS 4 Supply Fan speed 3",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 80.0,
#     "name": "ers-4-supply-fan-speed-3-49346",
#     "write": true
#   },
#   "49347": {
#     "title": "ERS 3 Supply Fan speed 3",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 80.0,
#     "name": "ers-3-supply-fan-speed-3-49347",
#     "write": true
#   },
#   "49348": {
#     "title": "ERS 2 Supply Fan speed 3",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 80.0,
#     "name": "ers-2-supply-fan-speed-3-49348",
#     "write": true
#   },
#   "49349": {
#     "title": "ERS 4 Supply Fan speed 2",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 30.0,
#     "name": "ers-4-supply-fan-speed-2-49349",
#     "write": true
#   },
#   "49350": {
#     "title": "ERS 3 Supply Fan speed 2",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 30.0,
#     "name": "ers-3-supply-fan-speed-2-49350",
#     "write": true
#   },
#   "49351": {
#     "title": "ERS 2 Supply Fan speed 2",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 30.0,
#     "name": "ers-2-supply-fan-speed-2-49351",
#     "write": true
#   },
#   "49352": {
#     "title": "ERS 4 Supply Fan speed 1",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 0.0,
#     "name": "ers-4-supply-fan-speed-1-49352",
#     "write": true
#   },
#   "49353": {
#     "title": "ERS 3 Supply Fan speed 1",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 0.0,
#     "name": "ers-3-supply-fan-speed-1-49353",
#     "write": true
#   },
#   "49354": {
#     "title": "ERS 2 Supply Fan speed 1",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 100.0,
#     "default": 0.0,
#     "name": "ers-2-supply-fan-speed-1-49354",
#     "write": true
#   },
#   "49355": {
#     "title": "ERS 4 Supply Fan speed normal",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 1.0,
#     "max": 100.0,
#     "default": 75.0,
#     "name": "ers-4-supply-fan-speed-normal-49355",
#     "write": true
#   },
#   "49356": {
#     "title": "ERS 3 Supply Fan speed normal",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 1.0,
#     "max": 100.0,
#     "default": 75.0,
#     "name": "ers-3-supply-fan-speed-normal-49356",
#     "write": true
#   },
#   "49357": {
#     "title": "ERS 2 Supply Fan speed normal",
#     "unit": "%",
#     "size": "u8",
#     "factor": 1,
#     "min": 1.0,
#     "max": 100.0,
#     "default": 75.0,
#     "name": "ers-2-supply-fan-speed-normal-49357",
#     "write": true
#   },
#   "49358": {
#     "title": "Night cooling",
#     "info": "If the fan should have a higher speed when there is a high room temp and a low outdoor temp.",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "night-cooling-49358",
#     "write": true
#   },
#   "49359": {
#     "title": "Night cooling",
#     "info": "If the fan should have a higher speed when there is a high room temp and a low outdoor temp.",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "night-cooling-49359",
#     "write": true
#   },
#   "49360": {
#     "title": "Night cooling",
#     "info": "If the fan should have a higher speed when there is a high room temp and a low outdoor temp.",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "night-cooling-49360",
#     "write": true
#   },
#   "49361": {
#     "title": "Start room temp. night cooling",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 20.0,
#     "max": 30.0,
#     "default": 25.0,
#     "name": "start-room-temp-night-cooling-49361",
#     "write": true
#   },
#   "49362": {
#     "title": "Start room temp. night cooling",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 20.0,
#     "max": 30.0,
#     "default": 25.0,
#     "name": "start-room-temp-night-cooling-49362",
#     "write": true
#   },
#   "49363": {
#     "title": "Start room temp. night cooling",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 20.0,
#     "max": 30.0,
#     "default": 25.0,
#     "name": "start-room-temp-night-cooling-49363",
#     "write": true
#   },
#   "49364": {
#     "title": "Night Cooling Min. diff.",
#     "info": "Minimum difference between room temp and outdoor temp to start night cooling",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 3.0,
#     "max": 10.0,
#     "default": 6.0,
#     "name": "night-cooling-min-diff-49364",
#     "write": true
#   },
#   "49365": {
#     "title": "Night Cooling Min. diff.",
#     "info": "Minimum difference between room temp and outdoor temp to start night cooling",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 3.0,
#     "max": 10.0,
#     "default": 6.0,
#     "name": "night-cooling-min-diff-49365",
#     "write": true
#   },
#   "49366": {
#     "title": "Night Cooling Min. diff.",
#     "info": "Minimum difference between room temp and outdoor temp to start night cooling",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 3.0,
#     "max": 10.0,
#     "default": 6.0,
#     "name": "night-cooling-min-diff-49366",
#     "write": true
#   },
#   "49367": {
#     "title": "ERS 4 accessory",
#     "info": "Activates the ERS accessory",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "ers-4-accessory-49367",
#     "write": true
#   },
#   "49368": {
#     "title": "ERS 3 accessory",
#     "info": "Activates the ERS accessory",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "ers-3-accessory-49368",
#     "write": true
#   },
#   "49369": {
#     "title": "ERS 2 accessory",
#     "info": "Activates the ERS accessory",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "ers-2-accessory-49369",
#     "write": true
#   },
#   "49370": {
#     "title": "External ERS 4 accessory min exhaust temp.",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 10.0,
#     "default": 5.0,
#     "name": "external-ers-4-accessory-min-exhaust-temp-49370",
#     "write": true
#   },
#   "49371": {
#     "title": "External ERS 3 accessory min exhaust temp.",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 10.0,
#     "default": 5.0,
#     "name": "external-ers-3-accessory-min-exhaust-temp-49371",
#     "write": true
#   },
#   "49372": {
#     "title": "External ERS 2 accessory min exhaust temp.",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 10.0,
#     "default": 5.0,
#     "name": "external-ers-2-accessory-min-exhaust-temp-49372",
#     "write": true
#   },
#   "49373": {
#     "title": "External ERS 4 accessory bypass temp.",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 2.0,
#     "max": 10.0,
#     "default": 4.0,
#     "name": "external-ers-4-accessory-bypass-temp-49373",
#     "write": true
#   },
#   "49374": {
#     "title": "External ERS 3 accessory bypass temp.",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 2.0,
#     "max": 10.0,
#     "default": 4.0,
#     "name": "external-ers-3-accessory-bypass-temp-49374",
#     "write": true
#   },
#   "49375": {
#     "title": "External ERS 2 accessory bypass temp.",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 2.0,
#     "max": 10.0,
#     "default": 4.0,
#     "name": "external-ers-2-accessory-bypass-temp-49375",
#     "write": true
#   },
#   "49376": {
#     "title": "External ERS 4 accessory bypass set temp.",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 5.0,
#     "max": 30.0,
#     "default": 25.0,
#     "name": "external-ers-4-accessory-bypass-set-temp-49376",
#     "write": true
#   },
#   "49377": {
#     "title": "External ERS 3 accessory bypass set temp.",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 5.0,
#     "max": 30.0,
#     "default": 25.0,
#     "name": "external-ers-3-accessory-bypass-set-temp-49377",
#     "write": true
#   },
#   "49378": {
#     "title": "External ERS 2 accessory bypass set temp.",
#     "unit": "\u00b0C",
#     "size": "u8",
#     "factor": 1,
#     "min": 5.0,
#     "max": 30.0,
#     "default": 25.0,
#     "name": "external-ers-2-accessory-bypass-set-temp-49378",
#     "write": true
#   },
#   "49379": {
#     "title": "External ERS 4 accessory bypass at heat",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "external-ers-4-accessory-bypass-at-heat-49379",
#     "write": true
#   },
#   "49380": {
#     "title": "External ERS 3 accessory bypass at heat",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "external-ers-3-accessory-bypass-at-heat-49380",
#     "write": true
#   },
#   "49381": {
#     "title": "External ERS 2 accessory bypass at heat",
#     "size": "u8",
#     "factor": 1,
#     "min": 0.0,
#     "max": 1.0,
#     "default": 0.0,
#     "name": "external-ers-2-accessory-bypass-at-heat-49381",
#     "write": true
#   },
#   "49430": {
#     "title": "AUX ERS Fire Place Guard",
#     "info": "Activates ERS Fire Place Guard",
#     "size": "u8",
#     "factor": 1,
#     "name": "aux-ers-fire-place-guard-49430",
#     "write": true
#   }
# }
